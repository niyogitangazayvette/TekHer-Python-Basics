# %% [markdown]
# # Practical_7: Matplotlib

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a simple line plot for `y = x` for `x` values ranging from 0 to 10.

# %%
import matplotlib.pyplot as plt
x = list(range(11)) 
y = x
plt.plot(x, y,'o-g')
plt.title("Line Plot of y = x")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 2:
# Plot `y = x^2` using Matplotlib for `x` values between -10 and 10.

# %%
import matplotlib.pyplot as plt
x = list(range(-10, 11))
y = [i**2 for i in x]
plt.plot(x, y,'.-r' )
plt.title("Plot of y = x²")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 3:
# Create a scatter plot with 50 random points where x and y values are between 0 and 10.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.uniform(0, 10, 50)
y = np.random.uniform(0, 10, 50)
plt.scatter(x, y, color='purple', marker='o')
plt.title('Scatter Plot of 50 Random Points')
plt.xlabel('x values')
plt.ylabel('y values')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 4:
# Plot a sine wave using Matplotlib for `x` values between 0 and 2π.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 2 * np.pi, 100) 
y = np.sin(x)
plt.plot(x, y, color='green', label='y = sin(x)')
plt.title('Sine Wave')
plt.xlabel('x (radians)')
plt.ylabel('y = sin(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 5:
# Create a bar chart for the following data: `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
import numpy as np
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]

plt.bar(categories, values)
plt.xlabel('Categories', color="purple")
plt.ylabel('Values')
plt.title('Bar Chart', color="purple")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 6:
# Create a histogram of 1000 random numbers generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30, density=True, alpha=0.6, color='g', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 1000 Random Numbers from a Normal Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 7:
# Plot two line plots on the same graph: `y1 = x^2` and `y2 = x^3` for `x` ranging from 0 to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 400)
y1 = x**2
y2 = x**3
plt.plot(x, y1, label='y1 = x^2')
plt.plot(x, y2, label='y2 = x^3')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Two Line Plots on the Same Graph')
plt.grid(True)
plt.legend
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 8:
# Add titles, axis labels, and a legend to the plot in Exercise 7.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 400)
y1 = x**2
y2 = x**3

plt.plot(x, y1, label='y1 = x^2')
plt.plot(x, y2, label='y2 = x^3')
plt.xlabel('value of x')
plt.ylabel('value of y')
plt.title('Two Line Plots on the Same Graph')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 9:
# Create a subplot with 2 rows and 1 column. Plot `y1 = x^2` in the first subplot and `y2 = x^3` in the second.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 400)
y1 = x**2
y2 = x**3

fig, ax1 = plt.subplots(1, 2, figsize=(8, 6))

ax1[0].plot(x, y1, label='y1 = x^2')
ax1[0].set_xlabel('x')
ax1[0].set_ylabel('y')
ax1[0].set_title('First Subplot')

ax1[1].plot(x, y2, label='y2 = x^3')
ax1[1].set_xlabel('x')
ax1[1].set_ylabel('y')
ax1[1].set_title('Second Subplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 10:
# Use a different color and linestyle for each line in a plot of three functions: `y1 = x`, `y2 = x^2`, and `y3 = x^3`.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 400)
y1 = x
y2 = x**2
y3 = x**3

plt.plot(x, y1, color='black', linestyle='--')
plt.plot(x, y2, color='yellow', linestyle='-')
plt.plot(x, y3, color='gray', linestyle=':')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Three Functions with Different Colors and Linestyles')
plt.legend(['y1 = x', 'y2 = x^2', 'y3 = x^3'])
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 11:
# Create a pie chart with 5 segments labeled A, B, C, D, and E, with values `[25, 35, 20, 15, 5]`.

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C', 'D', 'E']
sizes = [25, 35, 20, 15, 5]
colors = ['green','yellow','black','seagreen','gray']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors=colors, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal') 

plt.title('Pie Chart with 5 Segments')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 12:
# Create a horizontal bar chart with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
import numpy as np
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]

plt.barh(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Horizontal Bar Chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 13:
# Change the figure size of a line plot to 10x6 inches.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Set figure size to 10x6 inches
plt.figure(figsize=(10, 6))

# Plot the line
plt.plot(x, y, label='Sine Wave', color='blue')
plt.title("Line Plot with Figure Size 10x6")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 14:
# Plot a filled area under the curve of `y = x^2` for `x` ranging from 0 to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 400)
y = x**2

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(x, y, color='blue')
ax.fill_between(x, y, color='blue')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Filled Area Under the Curve of y = x^2')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 15:
# Change the style of the plot to `ggplot` and replot the sine wave from Exercise 4.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x)

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(x, y, color='black')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Sine Wave with ggplot Style')
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 16:
# Create a stacked bar chart for the following data: `Group A = [3, 5, 7]`, `Group B = [2, 6, 4]`, and `categories = ['X', 'Y', 'Z']`.

# %%
import numpy as np
import matplotlib.pyplot as plt

group_a = [3, 5, 7]
group_b = [2, 6, 4]
categories = ['X', 'Y', 'Z']

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(categories, group_a, label='Group A', color='yellow')
ax.bar(categories, group_b, label='Group B', color='black')
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Stacked Bar Chart')
ax.set_aspect('equal')

plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 17:
# Create a plot with multiple subplots in a 2x2 grid. Plot `y1 = x`, `y2 = x^2`, `y3 = x^3`, and `y4 = x^4`.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 400)
y1 = x
y2 = x**2
y3 = x**3
y4 = x**4

fig, ax = plt.subplots(2, 2, figsize=(10, 6))

ax[0, 0].plot(x, y1, label='y1 = x')
ax[0, 0].set_xlabel('x')
ax[0, 0].set_ylabel('y')
ax[0, 0].set_title('y1 = x')

ax[0, 1].plot(x, y2, label='y2 = x^2')
ax[0, 1].set_xlabel('x')
ax[0, 1].set_ylabel('y')
ax[0, 1].set_title('y2 = x^2')

ax[1, 0].plot(x, y3, label='y3 = x^3')
ax[1, 0].set_xlabel('x')
ax[1, 0].set_ylabel('y')
ax[1, 0].set_title('y3 = x^3')

ax[1, 1].plot(x, y4, label='y4 = x^4')
ax[1, 1].set_xlabel('x')
ax[1, 1].set_ylabel('y')
ax[1, 1].set_title('y4 = x^4')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 18:
# Create a heatmap using a 2D array of random values with shape (5, 5).

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.rand(5, 5)

fig, ax = plt.subplots(figsize=(10, 6))

im = ax.imshow(data, cmap='cividis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Heatmap of Random Values')

plt.colorbar(im)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 19:
# Add error bars to a bar plot with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`, assuming the error is 1 for each value.

# %%
import numpy as np
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
errors = [1, 1, 1, 1]

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(categories, values, yerr=errors, color='green')
ax.set_xlabel('Categories')
ax.set_ylabel('Values')
ax.set_title('Bar Plot with Error Bars')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 20:
# Plot a sine wave using a dashed line and a cosine wave using a solid line on the same plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 400)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(x, y1, linestyle='--', color='yellow')
ax.plot(x, y2, color='black')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Sine and Cosine Waves')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 21:
# Plot a contour plot for the function `z = sin(x) + cos(y)` over a grid of `x` and `y` values ranging from -5 to 5.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

fig, ax = plt.subplots(figsize=(10, 6))

im = ax.contourf(X, Y, Z, cmap='viridis')
cbar = ax.figure.colorbar(im)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Contour Plot of z = sin(x) + cos(y)')
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 22:
# Create a box plot for a dataset generated with 100 random numbers from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 1, 100)

fig, ax = plt.subplots(figsize=(8, 4))

ax.boxplot(data, vert=False)
ax.set_xlabel('Values')
ax.set_ylabel('Frequency')
ax.set_title('Box Plot of Random Numbers from Normal Distribution')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 23:
# Create a scatter plot with a color map applied to the points, where the color represents the value of the points.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

fig, ax = plt.subplots(figsize=(10, 6))

im = ax.scatter(X, Y, c=Z, cmap='inferno')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Scatter Plot with Color Map')
ax.set_aspect('equal')

plt.colorbar(im)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 24:
# Use Matplotlib to display an image from a file.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread(r"C:\Users\user\Downloads\balconies.png")
plt.imshow(image)
plt.axis('on')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 25:
# Create a plot with logarithmic scaling on both axes.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(1, 100, 100)
y = x**2

plt.figure(figsize=(8,6))
plt.plot(x, y, label='y = x^2')
plt.xscale('log')
plt.yscale('log')

plt.xlabel('X (log scale)')
plt.ylabel('Y (log scale)')
plt.title('Plot with Logarithmic Scale on Both Axes')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 26:
# Create a 3D plot of the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig, ax = plt.subplots(figsize=(10, 6))

ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Plot of z = x^2 + y^2')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 27:
# Create a radar chart with 5 variables and random values between 0 and 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
labels = ['A', 'B', 'C', 'D', 'E']
values = np.random.rand(5)
values = np.append(values, values[0])
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angles, values, color='blue', linewidth=2)
ax.fill(angles, values, color='blue', alpha=0.25)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
ax.set_ylim(0, 1)

plt.title("Radar Chart with 5 Random Variables")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 28:
# Create a violin plot to show the distribution of a dataset generated with 1000 random numbers from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.normal(0, 1, 1000)

fig, ax = plt.subplots(figsize=(10, 6))

ax.violinplot(data)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Violin Plot of Normal Distribution')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 29:
# Create a bar chart with different colors for each bar.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 10)
y1 = np.random.rand(10)
y2 = np.random.rand(10)
y3 = np.random.rand(10)

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x, y1, color='black')
ax.bar(x, y2, color='yellow')
ax.bar(x, y3, color='gray')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Bar Chart with Different Colors')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 30:
# Create a stem plot for the function `y = sin(x)` for `x` values between 0 and 2π.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots(figsize=(10, 6))

ax.stem(x, y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Stem Plot of y = sin(x)')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 31:
# Create a scatter plot with markers of different sizes.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 50)
y = np.random.rand(50)
sizes = np.random.randint(10, 100, 50)

fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(x, y, s=sizes, c='blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Scatter Plot with Markers of Different Sizes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 32:
# Plot a cumulative histogram of 1000 random numbers generated from a uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.uniform(0, 1, 1000)
plt.figure(figsize=(8, 5))
plt.hist(data, bins=30, cumulative=True, color='seagreen', edgecolor='black')
plt.title("Cumulative Histogram of Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Cumulative Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 33:
# Create a pie chart with custom colors for each segment.

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 20, 35]
colors = ['gray','black','yellow','lightgreen']

fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
ax.set_title('Pie Chart with Custom Colors')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 34:
# Create a plot with twin y-axes where one axis represents `y = x` and the other represents `y = x^2`.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y1 = x
y2 = x**2

fig, ax1 = plt.subplots(figsize=(8, 4))

ax1.plot(x, y1, color='yellow')
ax1.set_xlabel('x')
ax1.set_ylabel('y = x', color='yellow')
ax1.tick_params(axis='y', labelcolor='black')

ax2 = ax1.twinx()
ax2.plot(x, y2, color='black')
ax2.set_ylabel('y = x^2', color='black')
ax2.tick_params(axis='y', labelcolor='black')

fig.tight_layout()
ax1.set_title('Plot with Twin Y-Axes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 35:
# Plot a density plot of 1000 random values from a normal distribution.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = np.random.randn(1000)
sns.kdeplot(data, fill=True)
plt.title("Density Plot")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 36:
# Create a histogram and add a kernel density estimate (KDE) to the plot.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = np.random.randn(1000)
sns.histplot(data, kde=True, bins=30, color='yellow', edgecolor='black')
plt.title("Histogram with Kernel Density Estimate")
plt.xlabel("Value")
plt.ylabel("Frequency / Density")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 37:
# Add gridlines to a line plot and change the color and linestyle of the grid.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.random.rand(100)

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(x, y, color='blue')
ax.grid(color='gray', linestyle='--', linewidth=0.5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Line Plot with Gridlines')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 38:
# Create a bar chart with annotations showing the height of each bar above the bar.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 10)
y = np.random.rand(10)

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x, y)
for i in range(len(x)):
    ax.text(x[i], y[i], f"{y[i]:.2f}", ha='center', va='top')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Bar Chart with Annotations')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 39:
# Create a filled contour plot for the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig, ax = plt.subplots(figsize=(10, 6))

ax.contourf(X, Y, Z, cmap='RdYlGn')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Filled Contour Plot of z = x^2 + y^2')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 40:
# Create a stacked area plot using three random datasets.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y1 = np.random.rand(100)
y2 = np.random.rand(100)
y3 = np.random.rand(100)

fig, ax = plt.subplots(figsize=(10, 6))

ax.fill_between(x, y1, y2, alpha=0.2)
ax.fill_between(x, y1, y3, alpha=0.4)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Stacked Area Plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 41:
# Create a bar chart with error bars, where the error values are proportional to the bar values.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 10)
y = np.random.rand(10)
err = y * np.random.rand(10)

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(x, y, yerr=err, color='blue')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Bar Chart with Error Bars')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 42:
# Create a wind rose chart using random wind direction and speed data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from windrose import WindroseAxes
np.random.seed(42)
wind_directions = np.random.uniform(0, 360, 500)
wind_speeds = np.random.uniform(0, 15, 500)

# Create wind rose chart
ax = WindroseAxes.from_ax()
ax.bar(wind_directions, wind_speeds, normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
plt.title("Wind Rose Chart with Random Data")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 43:
# Plot a cumulative frequency curve for a dataset of 100 random numbers.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 100 random numbers (e.g., from normal distribution)
data = np.random.randn(100)

# Sort data
sorted_data = np.sort(data)

# Calculate cumulative frequencies (as proportions)
cum_freq = np.arange(1, len(data) + 1) / len(data)

# Plot cumulative frequency curve
plt.plot(sorted_data, cum_freq, marker='o', linestyle='-')
plt.title("Cumulative Frequency Curve")
plt.xlabel("Data values")
plt.ylabel("Cumulative Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 44:
# Create a waterfall chart using Matplotlib to show the changes in a sequence of values.

# %%
import matplotlib.pyplot as plt
import numpy as np
changes = [100, -20, 30, -10, 40, -30]
labels = ['Start', 'Step 1', 'Step 2', 'Step 3', 'Step 4', 'Step 5', 'End']
cumulative = np.insert(np.cumsum(changes), 0, 0)
fig, ax = plt.subplots(figsize=(8, 5))
colors = ['yellow' if x >= 0 else 'grey' for x in changes]
for i in range(len(changes)):
    ax.bar(i, changes[i], bottom=cumulative[i], color=colors[i])
ax.bar(len(changes), cumulative[-1], color='black')
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels)
ax.set_ylabel('Value')
ax.set_title('Waterfall Chart')

for i in range(len(changes)):
    y = cumulative[i] + changes[i]/2
    ax.text(i, y, f'{changes[i]:+}', ha='center', va='center', color='white', fontweight='bold')
ax.text(len(changes), cumulative[-1]/2, f'{cumulative[-1]:.0f}', ha='center', va='center', color='white', fontweight='bold')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 45:
# Use the `imshow` function to display a 10x10 matrix of random values as an image.

# %%
import numpy as np
import matplotlib.pyplot as plt
matrix = np.random.rand(10, 10)
plt.imshow(matrix, cmap='viridis')
plt.colorbar()  
plt.title('10x10 Random Matrix Displayed as Image')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 46:
# Create a line plot with different markers for each point.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5, 6]
y = [10, 12, 8, 15, 7, 13]
markers = ['o', 's', 'D', '^', 'v', '*']  
for i in range(len(x)):
    plt.plot(x[i], y[i], marker=markers[i], color='blue', markersize=10)
plt.plot(x, y, color='gray', linestyle='--')
plt.title("Line Plot with Different Markers")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 47:
# Create a time series plot using Matplotlib and plot random data over a range of dates.

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
start = datetime.date(2025, 6, 1)
dates = [start + datetime.timedelta(days=i) for i in range(30)]

values = np.random.randn(len(dates)).cumsum()

plt.plot(dates, values, marker='o')
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 48:
# Create a bar chart with bars colored by category.

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [10, 15, 7, 12]
colors = ['black', 'yellow', 'grey', 'seagreen'] 

# Create the bar chart
plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=colors)
plt.title("Bar Chart Colored by Category")
plt.xlabel("Category")
plt.ylabel("Value")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 49:
# Create a radar chart to visualize the strengths of five different attributes.

# %%
labels = ['Speed', 'Power', 'Skill', 'Agility', 'Endurance']
values = np.random.rand(5)
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False)
values = np.concatenate((values, [values[0]]))
angles = np.concatenate((angles, [angles[0]]))
fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
ax.plot(angles, values, 'o-', linewidth=2)
ax.fill(angles, values, alpha=0.25)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title("Radar Chart for Attributes")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 50:
# Create a 3D scatter plot with random values for x, y, and z.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z, color='blue', s=100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D Scatter Plot')
plt.show()

# %% [markdown]
# ---
